# %% [markdown]
# #     Introduction to Besides Blocks Data Science Lab using Hip-Hop Lyrics

# %% [markdown]
# Welcome to an innovative way of teaching and sharing the delights that comes when data, computational methods and culture collide. The goal of this lab is to connect cultural relevance to computing by introducing elementary techniques of natural language processing with a corpus of hip-hop data.
#
# Art is something that we don’t often think can be brought to bear on the so-called hard sciences. As a result, those of us who are gifted in the arts or are inclined in that direction, shy away from the sciences because we might believe in the false choice of choosing between the arts or the sciences. We want to change this false dichotomy by bringing the power of computational methods to investigate and explore the riches that are inherent in the arts. It is for this reason that we have chosen to use a corpus of hip-hop lyrics as the dataset on which we will practice our computational techniques.
#
# Hip-hop is a good candidate for several reasons: most people are already familiar with some aspects of the art form, and it is capable of inciting emotional responses from most people.

# %% [markdown]
# ###### At the end of this lab you will be able to build a visualization of the occurence of certain words in any rappers lyrics. Like what we have below.

# %%
# %%html
#
# <style>
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
# }
#
# </style>
#
# <div id="d3test"></div>
# Out:
# <style>
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .link {
#   stroke: #999;
#   stroke-opacity: .6;
# }
#
# </style>
#
# <div id="d3test"></div>

# %%
# %%javascript
# require(["//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min.js"], function (d3) {
# console.log(d3);
#
# var width = 960,
#     height = 500;
#
# var color = d3.scale.category20();
#
# var force = d3.layout.force()
#     .charge(-120)
#     .linkDistance(30)
#     .size([width, height]);
#
# var svg = d3.select("#d3test").append("svg")
#     .attr("width", width)
#     .attr("height", height);
#
# var graph = {
#   "nodes":[
#     {"name":"Myriel","group":1},
#     {"name":"Napoleon","group":1},
#     {"name":"Mlle.Baptistine","group":1},
#     {"name":"Mme.Magloire","group":1},
#     {"name":"CountessdeLo","group":1},
#     {"name":"Geborand","group":1},
#     {"name":"Champtercier","group":1},
#     {"name":"Cravatte","group":1},
#     {"name":"Count","group":1},
#     {"name":"OldMan","group":1},
#     {"name":"Labarre","group":2},
#     {"name":"Valjean","group":2},
#     {"name":"Marguerite","group":3},
#     {"name":"Mme.deR","group":2},
#     {"name":"Isabeau","group":2},
#     {"name":"Gervais","group":2},
#     {"name":"Tholomyes","group":3},
#     {"name":"Listolier","group":3},
#     {"name":"Fameuil","group":3},
#     {"name":"Blacheville","group":3},
#     {"name":"Favourite","group":3},
#     {"name":"Dahlia","group":3},
#     {"name":"Zephine","group":3},
#     {"name":"Fantine","group":3},
#     {"name":"Mme.Thenardier","group":4},
#     {"name":"Thenardier","group":4},
#     {"name":"Cosette","group":5},
#     {"name":"Javert","group":4},
#     {"name":"Fauchelevent","group":0},
#     {"name":"Bamatabois","group":2},
#     {"name":"Perpetue","group":3},
#     {"name":"Simplice","group":2},
#     {"name":"Scaufflaire","group":2},
#     {"name":"Woman1","group":2},
#     {"name":"Judge","group":2},
#     {"name":"Champmathieu","group":2},
#     {"name":"Brevet","group":2},
#     {"name":"Chenildieu","group":2},
#     {"name":"Cochepaille","group":2},
#     {"name":"Pontmercy","group":4},
#     {"name":"Boulatruelle","group":6},
#     {"name":"Eponine","group":4},
#     {"name":"Anzelma","group":4},
#     {"name":"Woman2","group":5},
#     {"name":"MotherInnocent","group":0},
#     {"name":"Gribier","group":0},
#     {"name":"Jondrette","group":7},
#     {"name":"Mme.Burgon","group":7},
#     {"name":"Gavroche","group":8},
#     {"name":"Gillenormand","group":5},
#     {"name":"Magnon","group":5},
#     {"name":"Mlle.Gillenormand","group":5},
#     {"name":"Mme.Pontmercy","group":5},
#     {"name":"Mlle.Vaubois","group":5},
#     {"name":"Lt.Gillenormand","group":5},
#     {"name":"Marius","group":8},
#     {"name":"BaronessT","group":5},
#     {"name":"Mabeuf","group":8},
#     {"name":"Enjolras","group":8},
#     {"name":"Combeferre","group":8},
#     {"name":"Prouvaire","group":8},
#     {"name":"Feuilly","group":8},
#     {"name":"Courfeyrac","group":8},
#     {"name":"Bahorel","group":8},
#     {"name":"Bossuet","group":8},
#     {"name":"Joly","group":8},
#     {"name":"Grantaire","group":8},
#     {"name":"MotherPlutarch","group":9},
#     {"name":"Gueulemer","group":4},
#     {"name":"Babet","group":4},
#     {"name":"Claquesous","group":4},
#     {"name":"Montparnasse","group":4},
#     {"name":"Toussaint","group":5},
#     {"name":"Child1","group":10},
#     {"name":"Child2","group":10},
#     {"name":"Brujon","group":4},
#     {"name":"Mme.Hucheloup","group":8}
#   ],
#   "links":[
#     {"source":1,"target":0,"value":1},
#     {"source":2,"target":0,"value":8},
#     {"source":3,"target":0,"value":10},
#     {"source":3,"target":2,"value":6},
#     {"source":4,"target":0,"value":1},
#     {"source":5,"target":0,"value":1},
#     {"source":6,"target":0,"value":1},
#     {"source":7,"target":0,"value":1},
#     {"source":8,"target":0,"value":2},
#     {"source":9,"target":0,"value":1},
#     {"source":11,"target":10,"value":1},
#     {"source":11,"target":3,"value":3},
#     {"source":11,"target":2,"value":3},
#     {"source":11,"target":0,"value":5},
#     {"source":12,"target":11,"value":1},
#     {"source":13,"target":11,"value":1},
#     {"source":14,"target":11,"value":1},
#     {"source":15,"target":11,"value":1},
#     {"source":17,"target":16,"value":4},
#     {"source":18,"target":16,"value":4},
#     {"source":18,"target":17,"value":4},
#     {"source":19,"target":16,"value":4},
#     {"source":19,"target":17,"value":4},
#     {"source":19,"target":18,"value":4},
#     {"source":20,"target":16,"value":3},
#     {"source":20,"target":17,"value":3},
#     {"source":20,"target":18,"value":3},
#     {"source":20,"target":19,"value":4},
#     {"source":21,"target":16,"value":3},
#     {"source":21,"target":17,"value":3},
#     {"source":21,"target":18,"value":3},
#     {"source":21,"target":19,"value":3},
#     {"source":21,"target":20,"value":5},
#     {"source":22,"target":16,"value":3},
#     {"source":22,"target":17,"value":3},
#     {"source":22,"target":18,"value":3},
#     {"source":22,"target":19,"value":3},
#     {"source":22,"target":20,"value":4},
#     {"source":22,"target":21,"value":4},
#     {"source":23,"target":16,"value":3},
#     {"source":23,"target":17,"value":3},
#     {"source":23,"target":18,"value":3},
#     {"source":23,"target":19,"value":3},
#     {"source":23,"target":20,"value":4},
#     {"source":23,"target":21,"value":4},
#     {"source":23,"target":22,"value":4},
#     {"source":23,"target":12,"value":2},
#     {"source":23,"target":11,"value":9},
#     {"source":24,"target":23,"value":2},
#     {"source":24,"target":11,"value":7},
#     {"source":25,"target":24,"value":13},
#     {"source":25,"target":23,"value":1},
#     {"source":25,"target":11,"value":12},
#     {"source":26,"target":24,"value":4},
#     {"source":26,"target":11,"value":31},
#     {"source":26,"target":16,"value":1},
#     {"source":26,"target":25,"value":1},
#     {"source":27,"target":11,"value":17},
#     {"source":27,"target":23,"value":5},
#     {"source":27,"target":25,"value":5},
#     {"source":27,"target":24,"value":1},
#     {"source":27,"target":26,"value":1},
#     {"source":28,"target":11,"value":8},
#     {"source":28,"target":27,"value":1},
#     {"source":29,"target":23,"value":1},
#     {"source":29,"target":27,"value":1},
#     {"source":29,"target":11,"value":2},
#     {"source":30,"target":23,"value":1},
#     {"source":31,"target":30,"value":2},
#     {"source":31,"target":11,"value":3},
#     {"source":31,"target":23,"value":2},
#     {"source":31,"target":27,"value":1},
#     {"source":32,"target":11,"value":1},
#     {"source":33,"target":11,"value":2},
#     {"source":33,"target":27,"value":1},
#     {"source":34,"target":11,"value":3},
#     {"source":34,"target":29,"value":2},
#     {"source":35,"target":11,"value":3},
#     {"source":35,"target":34,"value":3},
#     {"source":35,"target":29,"value":2},
#     {"source":36,"target":34,"value":2},
#     {"source":36,"target":35,"value":2},
#     {"source":36,"target":11,"value":2},
#     {"source":36,"target":29,"value":1},
#     {"source":37,"target":34,"value":2},
#     {"source":37,"target":35,"value":2},
#     {"source":37,"target":36,"value":2},
#     {"source":37,"target":11,"value":2},
#     {"source":37,"target":29,"value":1},
#     {"source":38,"target":34,"value":2},
#     {"source":38,"target":35,"value":2},
#     {"source":38,"target":36,"value":2},
#     {"source":38,"target":37,"value":2},
#     {"source":38,"target":11,"value":2},
#     {"source":38,"target":29,"value":1},
#     {"source":39,"target":25,"value":1},
#     {"source":40,"target":25,"value":1},
#     {"source":41,"target":24,"value":2},
#     {"source":41,"target":25,"value":3},
#     {"source":42,"target":41,"value":2},
#     {"source":42,"target":25,"value":2},
#     {"source":42,"target":24,"value":1},
#     {"source":43,"target":11,"value":3},
#     {"source":43,"target":26,"value":1},
#     {"source":43,"target":27,"value":1},
#     {"source":44,"target":28,"value":3},
#     {"source":44,"target":11,"value":1},
#     {"source":45,"target":28,"value":2},
#     {"source":47,"target":46,"value":1},
#     {"source":48,"target":47,"value":2},
#     {"source":48,"target":25,"value":1},
#     {"source":48,"target":27,"value":1},
#     {"source":48,"target":11,"value":1},
#     {"source":49,"target":26,"value":3},
#     {"source":49,"target":11,"value":2},
#     {"source":50,"target":49,"value":1},
#     {"source":50,"target":24,"value":1},
#     {"source":51,"target":49,"value":9},
#     {"source":51,"target":26,"value":2},
#     {"source":51,"target":11,"value":2},
#     {"source":52,"target":51,"value":1},
#     {"source":52,"target":39,"value":1},
#     {"source":53,"target":51,"value":1},
#     {"source":54,"target":51,"value":2},
#     {"source":54,"target":49,"value":1},
#     {"source":54,"target":26,"value":1},
#     {"source":55,"target":51,"value":6},
#     {"source":55,"target":49,"value":12},
#     {"source":55,"target":39,"value":1},
#     {"source":55,"target":54,"value":1},
#     {"source":55,"target":26,"value":21},
#     {"source":55,"target":11,"value":19},
#     {"source":55,"target":16,"value":1},
#     {"source":55,"target":25,"value":2},
#     {"source":55,"target":41,"value":5},
#     {"source":55,"target":48,"value":4},
#     {"source":56,"target":49,"value":1},
#     {"source":56,"target":55,"value":1},
#     {"source":57,"target":55,"value":1},
#     {"source":57,"target":41,"value":1},
#     {"source":57,"target":48,"value":1},
#     {"source":58,"target":55,"value":7},
#     {"source":58,"target":48,"value":7},
#     {"source":58,"target":27,"value":6},
#     {"source":58,"target":57,"value":1},
#     {"source":58,"target":11,"value":4},
#     {"source":59,"target":58,"value":15},
#     {"source":59,"target":55,"value":5},
#     {"source":59,"target":48,"value":6},
#     {"source":59,"target":57,"value":2},
#     {"source":60,"target":48,"value":1},
#     {"source":60,"target":58,"value":4},
#     {"source":60,"target":59,"value":2},
#     {"source":61,"target":48,"value":2},
#     {"source":61,"target":58,"value":6},
#     {"source":61,"target":60,"value":2},
#     {"source":61,"target":59,"value":5},
#     {"source":61,"target":57,"value":1},
#     {"source":61,"target":55,"value":1},
#     {"source":62,"target":55,"value":9},
#     {"source":62,"target":58,"value":17},
#     {"source":62,"target":59,"value":13},
#     {"source":62,"target":48,"value":7},
#     {"source":62,"target":57,"value":2},
#     {"source":62,"target":41,"value":1},
#     {"source":62,"target":61,"value":6},
#     {"source":62,"target":60,"value":3},
#     {"source":63,"target":59,"value":5},
#     {"source":63,"target":48,"value":5},
#     {"source":63,"target":62,"value":6},
#     {"source":63,"target":57,"value":2},
#     {"source":63,"target":58,"value":4},
#     {"source":63,"target":61,"value":3},
#     {"source":63,"target":60,"value":2},
#     {"source":63,"target":55,"value":1},
#     {"source":64,"target":55,"value":5},
#     {"source":64,"target":62,"value":12},
#     {"source":64,"target":48,"value":5},
#     {"source":64,"target":63,"value":4},
#     {"source":64,"target":58,"value":10},
#     {"source":64,"target":61,"value":6},
#     {"source":64,"target":60,"value":2},
#     {"source":64,"target":59,"value":9},
#     {"source":64,"target":57,"value":1},
#     {"source":64,"target":11,"value":1},
#     {"source":65,"target":63,"value":5},
#     {"source":65,"target":64,"value":7},
#     {"source":65,"target":48,"value":3},
#     {"source":65,"target":62,"value":5},
#     {"source":65,"target":58,"value":5},
#     {"source":65,"target":61,"value":5},
#     {"source":65,"target":60,"value":2},
#     {"source":65,"target":59,"value":5},
#     {"source":65,"target":57,"value":1},
#     {"source":65,"target":55,"value":2},
#     {"source":66,"target":64,"value":3},
#     {"source":66,"target":58,"value":3},
#     {"source":66,"target":59,"value":1},
#     {"source":66,"target":62,"value":2},
#     {"source":66,"target":65,"value":2},
#     {"source":66,"target":48,"value":1},
#     {"source":66,"target":63,"value":1},
#     {"source":66,"target":61,"value":1},
#     {"source":66,"target":60,"value":1},
#     {"source":67,"target":57,"value":3},
#     {"source":68,"target":25,"value":5},
#     {"source":68,"target":11,"value":1},
#     {"source":68,"target":24,"value":1},
#     {"source":68,"target":27,"value":1},
#     {"source":68,"target":48,"value":1},
#     {"source":68,"target":41,"value":1},
#     {"source":69,"target":25,"value":6},
#     {"source":69,"target":68,"value":6},
#     {"source":69,"target":11,"value":1},
#     {"source":69,"target":24,"value":1},
#     {"source":69,"target":27,"value":2},
#     {"source":69,"target":48,"value":1},
#     {"source":69,"target":41,"value":1},
#     {"source":70,"target":25,"value":4},
#     {"source":70,"target":69,"value":4},
#     {"source":70,"target":68,"value":4},
#     {"source":70,"target":11,"value":1},
#     {"source":70,"target":24,"value":1},
#     {"source":70,"target":27,"value":1},
#     {"source":70,"target":41,"value":1},
#     {"source":70,"target":58,"value":1},
#     {"source":71,"target":27,"value":1},
#     {"source":71,"target":69,"value":2},
#     {"source":71,"target":68,"value":2},
#     {"source":71,"target":70,"value":2},
#     {"source":71,"target":11,"value":1},
#     {"source":71,"target":48,"value":1},
#     {"source":71,"target":41,"value":1},
#     {"source":71,"target":25,"value":1},
#     {"source":72,"target":26,"value":2},
#     {"source":72,"target":27,"value":1},
#     {"source":72,"target":11,"value":1},
#     {"source":73,"target":48,"value":2},
#     {"source":74,"target":48,"value":2},
#     {"source":74,"target":73,"value":3},
#     {"source":75,"target":69,"value":3},
#     {"source":75,"target":68,"value":3},
#     {"source":75,"target":25,"value":3},
#     {"source":75,"target":48,"value":1},
#     {"source":75,"target":41,"value":1},
#     {"source":75,"target":70,"value":1},
#     {"source":75,"target":71,"value":1},
#     {"source":76,"target":64,"value":1},
#     {"source":76,"target":65,"value":1},
#     {"source":76,"target":66,"value":1},
#     {"source":76,"target":63,"value":1},
#     {"source":76,"target":62,"value":1},
#     {"source":76,"target":48,"value":1},
#     {"source":76,"target":58,"value":1}
#   ]
# };
#
# force
#   .nodes(graph.nodes)
#   .links(graph.links)
#   .start();
#
# var link = svg.selectAll(".link")
#   .data(graph.links)
#   .enter().append("line")
#   .attr("class", "link")
#   .style("stroke-width", function(d) { return Math.sqrt(d.value); });
#
# var node = svg.selectAll(".node")
#   .data(graph.nodes)
#   .enter().append("circle")
#   .attr("class", "node")
#   .attr("r", 5)
#   .style("fill", function(d) { return color(d.group); })
#   .call(force.drag);
#
# node.append("title")
#   .text(function(d) { return d.name; });
#
# force.on("tick", function() {
#     link.attr("x1", function(d) { return d.source.x; })
#         .attr("y1", function(d) { return d.source.y; })
#         .attr("x2", function(d) { return d.target.x; })
#         .attr("y2", function(d) { return d.target.y; });
#
#     node.attr("cx", function(d) { return d.x; })
#         .attr("cy", function(d) { return d.y; });
# });
# });

# %% [markdown]
# Don't let all that code you just saw scare you. By the time you are done with this tutorial, you too will be able to build even more compelling data visualizations.
# The previous code uses HTML and Javascript. HTML is used to create a canvas for the visualization, and javascript is used to build the visualization.

# %% [markdown]
# One of the reasons why I love python is that it is a language that lends itself well to things like building webapps as well as "hardcore" computational science like calculatings the orbits of planets and stuff like that. What we are interested in is doing a bit of data manipulation based on a hip-hop corpus. We are going to be doing something similar to what Matt Daniels did with the hip-hop vocabulary. We are going to get under the hood and create our own hypothesis.

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.npr.org/2014/05/05/309840473/yeezy-or-the-bard-whos-the-best-wordsmith-in-hip-hop width=700 height=500></iframe>')
# Out:
# <iframe src=http://www.npr.org/2014/05/05/309840473/yeezy-or-the-bard-whos-the-best-wordsmith-in-hip-hop width=700 height=500></iframe>

# %% [markdown]
# If you read this article, you will see that Matt used the first 35,000 lyrics of each artist. For the sake of simplicity, I am going to used the artist JayZ as the subject of our analysis. So lets get go collect the first 35,000 words of JayZ lyrical catalog.
#
# How are we going to do this you might ask? Well first off go to your favorite search engine and search for Jay Z lyrics. On the other hand, you can actually use the rap annotation site genius(http://rap.genius.com/) to get all that information and then some. According to Genius, Jay Z has a lot of songs. On average, most rap songs are usually set with 3 verses containing sixteen bars, or sixteen sentences each.
#
# <pre><code>
# 35000/(16 * 3)
# 729
# </code></pre>
# So if 16 by 3 = 48, and 48 goes into 35000 gives approximately 729 songs. That can't be right, even though Jay Z is prolific, he hasn't written 700+ songs. So I must have gotten my understanding wrong.

# %%
35000/(16 * 3)
# Out:
# 729

# %% [markdown]
# I proceeded under the false assumption that each lyric was a sentence. Now I can see that each lyric must mean each word instead. This brings me to an essential quality of a good problem solver and Computer Scientist, that ability to embrace failure. More on that later. So lets go back an reanalyse the numbers. I need to figure out how many words are in the average rap bar?
#
# In order to solve this we need to basically find every instance of Jay Z's lyric, scrape them off the internet, and then start number crunching on them. To make this process faster, I have already built something called a webscraper and scraped all his lyrics till Holy Grail. Hopefully that gives us more than enough data to get to 35,000 words. You can download these files at http://omoju.github.io/JayZ.zip If you unpack the zip file, you will see its made up of a bunch of text files. Take sometime and go through some the text file to see what they look like. For example the file JayZ_The Black Album_99 Problems.txt contains the lyrics to 99 problems.
#
# Now that we have these files, we are going to use some python packages (a package is also known as a library) to help us. The python natural language toolkit (NLTK) is one of the more popular python libraries that people use for natural langugage processing. In fact, Matt Daniels used it for his hip-hop vocabulary. You can learn more about NLTK here, http://www.nltk.org/book/. So lets import the toolkit. To import any package in python, you type in the keyword import, followed by the name of the toolkit.

# %%
import nltk

# %% [markdown]
# The nltk library has a lot of functions associated with it. The one we are going to use in partcular is called a Corpus reader. If you look up the definition of a corpus, you will see that it is just a collection of written text. The JayZ folder contains a corpora of Jay Z lyrics. The great thing about nltk is that it comes with built-in support for dozens of corpora. For example, NLTK includes a small selection of texts from the Project Gutenberg, which contains some 25,000 free electronic books. To see some of these books we can run the following query

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = 'JayZ'
wordlist = PlaintextCorpusReader(corpus_root, '.*')

# %% [markdown]
# Ah, there is Shakespeare's Macbeth, Hamlet, as well as Julius Cesar. There is also the King James version of the bible as well as Jane Austen's Emma. So lets get on to making our JayZ corpus.
#
# Based on my perusal of the nltk book, I know that there is a plaintext corpus reading function named PlaintextCorpusReader that I can use to make my corpus. So from nltk corpus function, which I access through the '.' (dot) operator, I import PlaintextCorpusReader
# <pre><code> from nltk.corpus import PlaintextCorpusReader</code></pre>
#
# I create a variable that I name corpus_root and assign the full system path location to where I unzipped the JayZ file I downloaded.
# <pre><code> corpus_root = 'JayZ'</code></pre>
#
# I then call the plain text corpus reader function with the root location and the token "'.'" that means grab every file in that folder.
# <pre><code> wordlist = PlaintextCorpusReader(corpus_root, '.*')</code></pre>
#
# I have adapted a function from nltk to reading in my corpus. This function is below. In order to make this function work, we will need to get some additional libraries of functions. In this case, we will need the regular expressions library named "re". So the first thing we need to do is import that package.

# %%
import re

## This displays three stats for each lyric text
## Average word length, average sentence length, the number of times each vocabulary item appears
## in the text 

def begin(wordlist, the_corpus): #process the files so I know what was read in
    for fileid in wordlist.fileids():
        raw = wordlist.raw(fileid)
        raw = re.split(r'\W+', raw) ## split the raw text into appropriate words 
        ## while I am cleaning up, I should strip out the word chorus followed by the next word
        the_corpus.extend(raw)
        print fileid

    return the_corpus

# %% [markdown]
# The function does something then you type in the following
# <pre><code> the_corpus = begin(wordlist, []) </code></pre>
# Now the_corpus contains all the lyrics. I wrote the begin function in a way that shows what lyrics were read in. You should have a similar output to the one below.
#
# The series of words that make up Jay Z's lyrics is now represented by a data structure type list, named the_corpus. This list data structure is the same exact computational mental model that we have already acquired with the list data structure we are already familiar with in <i>Snap!</i>. Hopefully, you are beginning to gain a better understand of how all the computational thinking skills you acquired in your learning of <i>Snap!</i> will carry over to solving any computation problem realized in any programming language.

# %%
the_corpus = begin(wordlist, [])
# Out:
# JayZ_American Gangster_American Dreamin.txt
# JayZ_American Gangster_American Gangster.txt
# JayZ_American Gangster_Blue Magic.txt
# JayZ_American Gangster_Fallin.txt
# JayZ_American Gangster_Hello Brooklyn 20.txt
# JayZ_American Gangster_I Know.txt
# JayZ_American Gangster_Ignorant Shit.txt
# JayZ_American Gangster_Intro.txt
# JayZ_American Gangster_No Hook.txt
# JayZ_American Gangster_Party Life.txt
# JayZ_American Gangster_Pray.txt
# JayZ_American Gangster_Say Hello.txt
# JayZ_American Gangster_Success.txt
# JayZ_American Gangster_Sweet.txt
# JayZ_The Black Album_99 Problems.txt
# JayZ_The Black Album_Allure.txt
# JayZ_The Black Album_Change Clothes.txt
# JayZ_The Black Album_December 4th.txt
# JayZ_The Black Album_Dirt Off Your Shoulder.txt
# JayZ_The Black Album_Encore.txt
# JayZ_The Black Album_Justify My Thug.txt
# JayZ_The Black Album_Lucifer.txt
# JayZ_The Black Album_Moment Of Clarity.txt
# JayZ_The Black Album_My 1st Song.txt
# JayZ_The Black Album_Threat.txt
# JayZ_The Blueprint 2: The Gift & The Curse_03 Bonnie  Clyde.txt
# JayZ_The Blueprint 2: The Gift & The Curse_2 Many Hoes.txt
# JayZ_The Blueprint 2: The Gift & The Curse_A Ballad For The Fallen Soldier.txt
# JayZ_The Blueprint 2: The Gift & The Curse_A Dream.txt
# JayZ_The Blueprint 2: The Gift & The Curse_All Around The World.txt
# JayZ_The Blueprint 2: The Gift & The Curse_As One.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Bitches  Sisters.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Blueprint 2.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Diamond Is Forever.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Excuse Me Miss.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Fuck All Nite.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Guns  Roses.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Hovi Baby.txt
# JayZ_The Blueprint 2: The Gift & The Curse_I Did It My Way.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Meet The Parents.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Nigga Please.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Poppin Tags.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Show You How.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Some How Some Way.txt
# JayZ_The Blueprint 2: The Gift & The Curse_Some People Hate.txt
# JayZ_The Blueprint 2: The Gift & The Curse_The Bounce.txt
# JayZ_The Blueprint 2: The Gift & The Curse_The Watcher 2.txt
# JayZ_The Blueprint 2: The Gift & The Curse_What They Gonna Do Part II.txt
# JayZ_The Blueprint 2: The Gift & The Curse_What They Gonna Do.txt
# JayZ_The Blueprint 3_A Star Is Born.txt
# JayZ_The Blueprint 3_Already Home.txt
# JayZ_The Blueprint 3_Empire State Of Mind.txt
# JayZ_The Blueprint 3_Hate.txt
# JayZ_The Blueprint 3_Off That.txt
# JayZ_The Blueprint 3_On To The Next One.txt
# JayZ_The Blueprint 3_Real As It Gets.txt
# JayZ_The Blueprint 3_Reminder.txt
# JayZ_The Blueprint 3_Run This Town.txt
# JayZ_The Blueprint 3_So Ambitious.txt
# JayZ_The Blueprint 3_Thank You.txt
# JayZ_The Blueprint 3_Venus Vs Mars.txt
# JayZ_The Blueprint 3_What We Talkin About.txt
# JayZ_The Blueprint 3_Young Forever.txt
# JayZ_The Blueprint_All I Need.txt
# JayZ_The Blueprint_Girls Girls Girls.txt
# JayZ_The Blueprint_Hola Hovito.txt
# JayZ_The Blueprint_Jigga That Nigga.txt
# JayZ_The Blueprint_Never Change.txt
# JayZ_The Blueprint_Renegade.txt
# JayZ_The Blueprint_Song Cry.txt
# JayZ_The Blueprint_Takeover.txt
# JayZ_The Blueprint_The Best Of Both Worlds.txt
# JayZ_The Blueprint_The Rulers Back.txt
# JayZ_The Blueprint_U Dont Know.txt

# %%
len(the_corpus)
# Out:
# 46885

# %% [markdown]
# We have finally gotten our Jay Z Corpus! The data that we collected has a 46,890 words. You can see for yourself by running the len (python function for figuring out the length of a list) on the_corpus.
# <pre><code> len(the_corpus) </code></pre>
# The corpus is stored in a list data structure, which lends itself to list manipulation techniques. You can see all the ways you can interact with a list in the python documentation here https://docs.python.org/2/tutorial/datastructures.html

# %%
 the_corpus[320:350]
# Out:
# ['It',
#  's',
#  'like',
#  'Tony',
#  'LaRussa',
#  'On',
#  'how',
#  'you',
#  'play',
#  'your',
#  'cards',
#  'You',
#  'all',
#  'ain',
#  't',
#  'fucking',
#  'with',
#  'me',
#  'The',
#  'ironies',
#  'are',
#  'And',
#  'at',
#  'all',
#  'costs',
#  'better',
#  'avoid',
#  'these',
#  'bars',
#  'Now']

# %%
wordlist.fileids()
# Out:
# ['JayZ_American Gangster_American Dreamin.txt',
#  'JayZ_American Gangster_American Gangster.txt',
#  'JayZ_American Gangster_Blue Magic.txt',
#  'JayZ_American Gangster_Fallin.txt',
#  'JayZ_American Gangster_Hello Brooklyn 20.txt',
#  'JayZ_American Gangster_I Know.txt',
#  'JayZ_American Gangster_Ignorant Shit.txt',
#  'JayZ_American Gangster_Intro.txt',
#  'JayZ_American Gangster_No Hook.txt',
#  'JayZ_American Gangster_Party Life.txt',
#  'JayZ_American Gangster_Pray.txt',
#  'JayZ_American Gangster_Say Hello.txt',
#  'JayZ_American Gangster_Success.txt',
#  'JayZ_American Gangster_Sweet.txt',
#  'JayZ_The Black Album_99 Problems.txt',
#  'JayZ_The Black Album_Allure.txt',
#  'JayZ_The Black Album_Change Clothes.txt',
#  'JayZ_The Black Album_December 4th.txt',
#  'JayZ_The Black Album_Dirt Off Your Shoulder.txt',
#  'JayZ_The Black Album_Encore.txt',
#  'JayZ_The Black Album_Justify My Thug.txt',
#  'JayZ_The Black Album_Lucifer.txt',
#  'JayZ_The Black Album_Moment Of Clarity.txt',
#  'JayZ_The Black Album_My 1st Song.txt',
#  'JayZ_The Black Album_Threat.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_03 Bonnie  Clyde.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_2 Many Hoes.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_A Ballad For The Fallen Soldier.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_A Dream.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_All Around The World.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_As One.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Bitches  Sisters.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Blueprint 2.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Diamond Is Forever.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Excuse Me Miss.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Fuck All Nite.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Guns  Roses.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Hovi Baby.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_I Did It My Way.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Meet The Parents.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Nigga Please.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Poppin Tags.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Show You How.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Some How Some Way.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_Some People Hate.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_The Bounce.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_The Watcher 2.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_What They Gonna Do Part II.txt',
#  'JayZ_The Blueprint 2: The Gift & The Curse_What They Gonna Do.txt',
#  'JayZ_The Blueprint 3_A Star Is Born.txt',
#  'JayZ_The Blueprint 3_Already Home.txt',
#  'JayZ_The Blueprint 3_Empire State Of Mind.txt',
#  'JayZ_The Blueprint 3_Hate.txt',
#  'JayZ_The Blueprint 3_Off That.txt',
#  'JayZ_The Blueprint 3_On To The Next One.txt',
#  'JayZ_The Blueprint 3_Real As It Gets.txt',
#  'JayZ_The Blueprint 3_Reminder.txt',
#  'JayZ_The Blueprint 3_Run This Town.txt',
#  'JayZ_The Blueprint 3_So Ambitious.txt',
#  'JayZ_The Blueprint 3_Thank You.txt',
#  'JayZ_The Blueprint 3_Venus Vs Mars.txt',
#  'JayZ_The Blueprint 3_What We Talkin About.txt',
#  'JayZ_The Blueprint 3_Young Forever.txt',
#  'JayZ_The Blueprint_All I Need.txt',
#  'JayZ_The Blueprint_Girls Girls Girls.txt',
#  'JayZ_The Blueprint_Hola Hovito.txt',
#  'JayZ_The Blueprint_Jigga That Nigga.txt',
#  'JayZ_The Blueprint_Never Change.txt',
#  'JayZ_The Blueprint_Renegade.txt',
#  'JayZ_The Blueprint_Song Cry.txt',
#  'JayZ_The Blueprint_Takeover.txt',
#  'JayZ_The Blueprint_The Best Of Both Worlds.txt',
#  'JayZ_The Blueprint_The Rulers Back.txt',
#  'JayZ_The Blueprint_U Dont Know.txt']

# %%
# %pylab inline
cfd = nltk.ConditionalFreqDist(
          (target, fileid)
           for fileid in wordlist.fileids()
           for w in wordlist.words(fileid)
           for target in ['dope', 'drugs', 'white', 'snow', 'pound']
          if w.lower().startswith(target))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cfd.plot()

# %%
fileid = wordlist.fileids()
fileid[15]
# Out:
# 'JayZ_The Black Album_Allure.txt'

# %%
Ame = wordlist.words(fileid[15])

# %%
wordlist.words(fileid[15])
# Out:
# ['Young', '!', 'For', 'life', 'Once', 'again', 'it', ...]

# %%
len(Ame)
# Out:
# 767

# %% [markdown]
# So that was the hard way to get data. Now, lets access rap lyrics the easy way using an api that was written for rap genius, courtesy <a href="https://twitter.com/Ed_Forson">Ed Forson</a>, you can read more about it http://genius-api.com/

# %%
import urllib
import urllib2
import json
url = 'http://genius-api.com/api/artistInfo'
values = {'name' : 'Gza',
          'genre' : 'rap'}
data = urllib.urlencode(values)
req = urllib2.Request(url, data)

# %%
response = urllib2.urlopen(req)

# %%
the_page = response.read()

# %%
decoded_data = json.loads(the_page)

# %%
pprint(decoded_data)
# Out:
# {u'link': u'http://rapgenius.com/artists/GZA',
#  u'name': u'GZA',
#  u'popularSongs': [{u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-4th-chamber-lyrics',
#                     u'name': u'4th Chamber (Ft. Ghostface Killah, Killah Priest & RZA) prod. by RZA'},
#                    {u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-liquid-swords-lyrics',
#                     u'name': u'Liquid Swords prod. by RZA'},
#                    {u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-shadowboxin-lyrics',
#                     u'name': u"Shadowboxin' (Ft. Method Man) prod. by RZA"},
#                    {u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-duel-of-the-iron-mic-lyrics',
#                     u'name': u"Duel of the Iron Mic (Ft. Inspectah Deck, Masta Killa & Ol' Dirty Bastard) prod. by RZA"},
#                    {u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Raekwon-guillotine-swordz-lyrics',
#                     u'name': u'Guillotine (Swordz) by Raekwon  (Ft. Ghostface Killah & Inspectah Deck) prod. by RZA'},
#                    {u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-bible-basic-instructions-before-leaving-earth-lyrics',
#                     u'name': u'B.I.B.L.E. (Basic Instructions Before Leaving Earth) (Ft. Killah Priest) prod. by 4th Disciple'},
#                    {u'artists': u'http://rapgenius.com/artists/GZA',
#                     u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-cold-world-lyrics',
#                     u'name': u'Cold World (Ft. Inspectah Deck) prod. by RZA'}],
#  u'songs': [{u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-4th-chamber-lyrics',
#              u'name': u'4th Chamber (Ft. Ghostface Killah, Killah Priest & RZA) prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-liquid-swords-lyrics',
#              u'name': u'Liquid Swords prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-shadowboxin-lyrics',
#              u'name': u"Shadowboxin' (Ft. Method Man) prod. by RZA"},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-duel-of-the-iron-mic-lyrics',
#              u'name': u"Duel of the Iron Mic (Ft. Inspectah Deck, Masta Killa & Ol' Dirty Bastard) prod. by RZA"},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Raekwon-guillotine-swordz-lyrics',
#              u'name': u'Guillotine (Swordz) by Raekwon  (Ft. Ghostface Killah & Inspectah Deck) prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-bible-basic-instructions-before-leaving-earth-lyrics',
#              u'name': u'B.I.B.L.E. (Basic Instructions Before Leaving Earth) (Ft. Killah Priest) prod. by 4th Disciple'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-cold-world-lyrics',
#              u'name': u'Cold World (Ft. Inspectah Deck) prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-0-finance-lyrics',
#              u'name': u'0% Finance prod. by Jose "Choco" Reynoso'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-1112-lyrics',
#              u'name': u'1112 (Ft. Killah Priest, Masta Killa & Njeri) prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-4th-chamber-lyrics',
#              u'name': u'4th Chamber (Ft. Ghostface Killah, Killah Priest & RZA) prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-7-pounds-lyrics',
#              u'name': u'7 Pounds prod. by Black Milk & DJ Preservation'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Athen-97-till-infinity-lyrics',
#              u'name': u'97 till infinity by Athen  (Ft. Alex King, Dante, Delgado & Lil Wiz) prod. by August Martin High School, Christopher Emdin & Science Genius'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-advance-pawns-lyrics',
#              u'name': u'Advance Pawns (Ft. Raekwon & RZA) prod. by Muggs'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-all-in-together-now-lyrics',
#              u'name': u'All In Together Now (Ft. RZA) prod. by Muggs'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-alphabets-lyrics',
#              u'name': u'Alphabets prod. by Dakimh & True Master'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-amplified-sample-lyrics',
#              u'name': u'Amplified Sample prod. by Mathematics'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-animal-planet-lyrics',
#              u'name': u'Animal Planet prod. by Bink! & Tyquan Walker'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Wisemen-associated-lyrics',
#              u'name': u'Associated by Wisemen'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-auto-bio-lyrics',
#              u'name': u'Auto Bio prod. by Jay Garfield'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-beneath-the-surface-lyrics',
#              u'name': u'Beneath the Surface (Ft. Killah Priest) prod. by Inspectah Deck'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-bible-basic-instructions-before-leaving-earth-lyrics',
#              u'name': u'B.I.B.L.E. (Basic Instructions Before Leaving Earth) (Ft. Killah Priest) prod. by 4th Disciple'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Afu-ra-bigacts-littleacts-lyrics',
#              u'name': u'Bigacts, Littleacts by Afu-Ra  prod. by True Master'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-big-bang-rap-lyrics',
#              u'name': u'Big Bang Rap'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-breaker-breaker-lyrics',
#              u'name': u'Breaker, Breaker prod. by Arabian Knight'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Big-daddy-kane-cameo-afro-lyrics',
#              u'name': u'Cameo Afro by Big Daddy Kane  (Ft. Suga Bang Bang) prod. by RZA'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-chasing-dreams-lyrics',
#              u'name': u'Chasing Dreams (Ft. Esera Tualo & Rob Report)'},
#             {u'artists': u'http://rapgenius.com/artists/GZA',
#              u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-cinema-lyrics',
#              u'name': u'Cinema (Ft. Justice Kareem) prod. by Arabian Knight & Chimpo'}]}

# %%
decoded_data.viewkeys()
# Out:
# dict_keys([u'popularSongs', u'link', u'name', u'songs'])

# %%
decoded_data.get('songs')
# Out:
# [{u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-4th-chamber-lyrics',
#   u'name': u'4th Chamber (Ft. Ghostface Killah, Killah Priest & RZA) prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-liquid-swords-lyrics',
#   u'name': u'Liquid Swords prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-shadowboxin-lyrics',
#   u'name': u"Shadowboxin' (Ft. Method Man) prod. by RZA"},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-duel-of-the-iron-mic-lyrics',
#   u'name': u"Duel of the Iron Mic (Ft. Inspectah Deck, Masta Killa & Ol' Dirty Bastard) prod. by RZA"},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Raekwon-guillotine-swordz-lyrics',
#   u'name': u'Guillotine (Swordz) by Raekwon  (Ft. Ghostface Killah & Inspectah Deck) prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-bible-basic-instructions-before-leaving-earth-lyrics',
#   u'name': u'B.I.B.L.E. (Basic Instructions Before Leaving Earth) (Ft. Killah Priest) prod. by 4th Disciple'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-cold-world-lyrics',
#   u'name': u'Cold World (Ft. Inspectah Deck) prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-0-finance-lyrics',
#   u'name': u'0% Finance prod. by Jose "Choco" Reynoso'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-1112-lyrics',
#   u'name': u'1112 (Ft. Killah Priest, Masta Killa & Njeri) prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-4th-chamber-lyrics',
#   u'name': u'4th Chamber (Ft. Ghostface Killah, Killah Priest & RZA) prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-7-pounds-lyrics',
#   u'name': u'7 Pounds prod. by Black Milk & DJ Preservation'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Athen-97-till-infinity-lyrics',
#   u'name': u'97 till infinity by Athen  (Ft. Alex King, Dante, Delgado & Lil Wiz) prod. by August Martin High School, Christopher Emdin & Science Genius'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-advance-pawns-lyrics',
#   u'name': u'Advance Pawns (Ft. Raekwon & RZA) prod. by Muggs'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-all-in-together-now-lyrics',
#   u'name': u'All In Together Now (Ft. RZA) prod. by Muggs'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-alphabets-lyrics',
#   u'name': u'Alphabets prod. by Dakimh & True Master'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-amplified-sample-lyrics',
#   u'name': u'Amplified Sample prod. by Mathematics'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-animal-planet-lyrics',
#   u'name': u'Animal Planet prod. by Bink! & Tyquan Walker'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Wisemen-associated-lyrics',
#   u'name': u'Associated by Wisemen'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-auto-bio-lyrics',
#   u'name': u'Auto Bio prod. by Jay Garfield'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-beneath-the-surface-lyrics',
#   u'name': u'Beneath the Surface (Ft. Killah Priest) prod. by Inspectah Deck'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-bible-basic-instructions-before-leaving-earth-lyrics',
#   u'name': u'B.I.B.L.E. (Basic Instructions Before Leaving Earth) (Ft. Killah Priest) prod. by 4th Disciple'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Afu-ra-bigacts-littleacts-lyrics',
#   u'name': u'Bigacts, Littleacts by Afu-Ra  prod. by True Master'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-big-bang-rap-lyrics',
#   u'name': u'Big Bang Rap'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-breaker-breaker-lyrics',
#   u'name': u'Breaker, Breaker prod. by Arabian Knight'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Big-daddy-kane-cameo-afro-lyrics',
#   u'name': u'Cameo Afro by Big Daddy Kane  (Ft. Suga Bang Bang) prod. by RZA'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-chasing-dreams-lyrics',
#   u'name': u'Chasing Dreams (Ft. Esera Tualo & Rob Report)'},
#  {u'artists': u'http://rapgenius.com/artists/GZA',
#   u'link': u'http://rapgenius.comhttp://rap.genius.com/Gza-cinema-lyrics',
#   u'name': u'Cinema (Ft. Justice Kareem) prod. by Arabian Knight & Chimpo'}]

# %%
song_url = 'http://genius-api.com/api/songInfo' #Song information
artist_url = 'http://genius-api.com/api/artistInfo' #artist info
values = {'name' : 'Liquid Swords',
          'genre' : 'rap'}

# %%
data = urllib.urlencode(values)
req = urllib2.Request(song_url, data)

# %%
urllib2.Request(song_url, data)
# Out:
# <urllib2.Request instance at 0x1088eb248>

# %%
req = urllib2.Request(song_url, data)

# %%
response = urllib2.urlopen(req)

# %%
song_info = response.read()

# %%
decoded_data = json.loads(song_info)

# %%
decoded_data
# Out:
# [{u'artists': u'',
#   u'link': u'http://rap.genius.com/Gza-liquid-swords-lyrics',
#   u'name': u'Liquid Swords by\xa0GZA'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Gza-liquid-swords-album-art-lyrics',
#   u'name': u'Liquid Swords Album Art by\xa0GZA'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Apathy-liquid-swords-tribute-pt-1-lyrics',
#   u'name': u'Liquid Swords Tribute Pt. 1 by\xa0Apathy'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Skyart-and-skyfordstephens-liquid-swords-vs-my-beautiful-dark-twisted-fantasy-lyrics',
#   u'name': u'Liquid Swords VS My Beautiful Dark Twisted Fantasy by\xa0SkyArt\xa0and\xa0SkyfordStephens'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Pharrell-williams-liquid-swords-lyrics',
#   u'name': u'Liquid Swords by\xa0Pharrell\xa0Williams\xa0(Ft.\xa0DJ\xa0Drama)'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/B4da-liquid-swords-review-lyrics',
#   u'name': u'"Liquid Swords" Review by\xa0B4DA$$'},
#  {u'artists': u'',
#   u'link': u'http://lit.genius.com/Jeff-gangwer-tongues-at-work-liquid-swords-annotated',
#   u'name': u'Tongues at Work / Liquid Swords by\xa0Jeff\xa0Gangwer'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Drake-bollywood-flow-lyrics',
#   u'name': u'Bollywood Flow by\xa0Drake'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Gza-paper-plates-lyrics',
#   u'name': u'Paper Plates by\xa0GZA'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/William-the-the-hardest-ever-lyrics',
#   u'name': u'T.H.E. (The Hardest Ever) by\xa0Will.I.Am\xa0(Ft.\xa0Jennifer\xa0Lopez\xa0&\xa0Mick\xa0Jagger)'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Rhyme-asylum-unreasonable-lyrics',
#   u'name': u'Unreasonable by\xa0Rhyme\xa0Asylum\xa0(Ft.\xa0Diabolic)'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Drake-1xtra-freestyle-lyrics',
#   u'name': u'1Xtra Freestyle by\xa0Drake'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Windchill-pay-homage-lyrics',
#   u'name': u'Pay homage by\xa0Windchill'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Talib-kweli-talib-kwelis-top-100-hip-hop-albums-lyrics',
#   u'name': u"Talib Kweli's Top 100 Hip Hop Albums by\xa0Talib\xa0Kweli"},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Gza-lyrical-swords-lyrics',
#   u'name': u'Lyrical Swords by\xa0GZA\xa0(Ft.\xa0Ras\xa0Kass)'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Big-baby-gandhi-blue-magic-lyrics',
#   u'name': u'Blue Magic by\xa0Big\xa0Baby\xa0Gandhi\xa0(Ft.\xa0Das\xa0Racist)'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Ra-the-rugged-man-complex-superiority-lyrics',
#   u'name': u'Complex Superiority by\xa0R.A.\xa0The\xa0Rugged\xa0Man'},
#  {u'artists': u'',
#   u'link': u'http://news.genius.com/Survey-week-2014-popularity-poll-results-annotated',
#   u'name': u'Popularity Poll Results by\xa0Survey\xa0Week\xa02014\xa0(Ft.\xa0Jason\xa0D.\xa0Morris)'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Alpha-wann-alpha-wann-marche-arriere-lyrics',
#   u'name': u'Alpha Wann - Marche Arri\xe8re by\xa0Alpha\xa0Wann'},
#  {u'artists': u'',
#   u'link': u'http://rap.genius.com/Supastition-yada-yada-lyrics',
#   u'name': u'Yada Yada by\xa0Supastition'}]

# %%
lyric_url = 'http://genius-api.com/api/lyricsInfo'
parameters = {'link':'http://rapgenius.com/Gza-liquid-swords-lyrics',
          'genre' : 'rap'}
data = urllib.urlencode(parameters)
req = urllib2.Request(url, data)

# %%
req = urllib2.Request(lyric_url, data)
response = urllib2.urlopen(req)
lyric_info = response.read()
decoded_data = json.loads(lyric_info)

# %%
pprint(decoded_data)
# Out:
# {u'explanations': {u'105123': u'\u201cDown by law\u201d is what an aspiring rapper had to be before being declared an emcee. Also the name of a movie made in 1986 and MC Shan\u2019s debut album',
#                    u'1129030': u'Table stacks (steaks) a verse on the gamble. So my energy is felt once the cards are dealt because I\u2019m talking about gambling.GZA is so wealthy that his minimum bet in poker is so high others would think twice before matching it\n\nOnce the cards are dealt, the weight of the money riding on the hand makes it seem like his opponents have been hit by black belts and cyclones due to how good GZA\u2019s luck is\n\nIn the second half of these rhymes it becomes clear that he uses the card game gamble as a metaphor for his rap battling skills, his minimum bet is a verse and the energy is felt when they\u2019re battling. Then the GZA hits the verse with the impact of roundhouse kicks from black belts attacking the mic like cyclones or typhoons, it has nothing to do with his gambling and luck!',
#                    u'1129037': u'Just means around the clock\u2026 form 12 to 12. And \u201chigh noon\u201d rhymes with \u201ctyphoons\u201d.Technically, though, midnight to high noon is only twelve hours; no doubt GZA wants some time at the end of the day to rest and decompress.\n\nHigh noon is an appropriate time for a duel.',
#                    u'1129040': u'Like mega \u2014 tons. Just said it \u2018megaton\u2019.Really like the scientific register here \u2014 \u201cmegaton\u201d and the suggestion that rhymes travel like sound or light. This is one of the things that marks GZA out as a uniquely intelligent lyricist.',
#                    u'1129043': u'Either this logo or the Wu logo. I have a vaccination mark. Anyone over 30 or 40 years old in America has one. It\u2019s like a barcode.',
#                    u'114125': u'GZA\u2019s flow is too quick for other people to just bite off his lyrics; they have to write down his lyrics before they can steal from him..',
#                    u'122127': u'Dad: Listen to the GZA son. Listen to the sound of the Wu.\nSon: Dad you were right. Wu Tang is for the Children\n\nNote the connection of key as C\u2019s are a low key.  A seashell held to the ear resonates outside and bodily sounds and produces a bass-heavy hum, ergo low-key, hence a c-shell.',
#                    u'122135': u'Just means around the clock\u2026 form 12 to 12. And \u201chigh noon\u201d rhymes with \u201ctyphoons\u201d.Technically, though, midnight to high noon is only twelve hours; no doubt GZA wants some time at the end of the day to rest and decompress.\n\nHigh noon is an appropriate time for a duel.',
#                    u'1266684': u'Can mean 2 things:\n1. Literally, you can get shot up or hurt if you or the boys you roll with ain\u2019t right.\n2. \u201cNot rolling smart\u201d, as in falling in love with trick ass bitches who are gonna fuck you over.',
#                    u'1266694': u"Many artists on Wu Tang were somewhat known before Wu Tang but when Wu Tang dropped their debut album Enter the Wu-Tang (36 chambers) in 93', these artists potential was seen and they all became huge.",
#                    u'1291703': u'YES WE ARE',
#                    u'1463153': u'The hook is a mythologization of the birth of hip hop: \u201cWhen the MCs came\u2026\u201d and created what we know as hip hop culture.',
#                    u'1463155': u'The \u201cPete\u201d at the end of the second line is a reference to generally revered producer Pete Rock.\n\nEmcee\u2019s had to snort coke to act wild and get hype while Pete could rock the crowd with his music. There might also be a double meaning with crack cocaine aka \u201crock\u201d\n\nIn the 1980s there was a Crack Epidemic which hit New York City, particularly the Bronx hard.',
#                    u'1463156': u'RZA sings chorus with GZA on the hook, and the final lines are a shout out to his production on the song and album.',
#                    u'1463158': u'A poetic evocation of the intellectual work of the MC: \u201cto spark the brain,\u201d to enlighten listeners.\n\n\u201cThe building to be born\u201d is a 5% reference, and another mythic image. Perhaps the \u201cblack urban renewal\u201d of hip hop culture that would revitalize  the urban decay of late 70s Bronx (Rose, Black Noise 61).',
#                    u'1472081': u'GZA is commenting on his ability to rhyme, where his flow is comparable to blood flowing from a dead person\u2019s artery, swift and constant.\n\nHe also compares it to the flow of a drug inserted intravenously through a syringe, used by a dope fiend.',
#                    u'152367': u'Like mega \u2014 tons. Just said it \u2018megaton\u2019.Really like the scientific register here \u2014 \u201cmegaton\u201d and the suggestion that rhymes travel like sound or light. This is one of the things that marks GZA out as a uniquely intelligent lyricist.',
#                    u'159234': u'DL = down-low\n\nHe came to the party with his crew; but left silently to do his own thing\u2026',
#                    u'1741918': u'The literal definition of \u201cblunted\u201d is \u201cnot sharp\u201d, \u201cdull\u201d and \u201cslow to understand or perceive\u201d.\n\nStemming from the previous line (\u201cclouds of smoke, of natural blends of weed\u201d), the only \u201ccircumstance\u201d when the GZA is \u201cblunted\u201d is when he smokes blunts:',
#                    u'1741926': u'GZA embraces his independence. Instead of mindlessly following all laws, he chooses to follow the laws that are civil.\n\nWhen Wu-Tang Clan\u2019s first album, 36 Chambers, debuted, it was the beginning of Wu-Tang Clan\u2019s influence to Hip-Hop culture. GZA and the rest of Wu-Tang Clan took Hip-Hop culture to new heights and uncharted territory, setting new standards, styles and \u201claws\u201d in Hip-Hop.\n\nAn example of how Wu-Tang set new laws:\nFrom Wikipedia, \u201cThe distinctive sound of Enter the Wu-Tang has been credited for creating a blueprint for hardcore hip hop in the mid-1990s\u201d',
#                    u'1774226': u'\u201cop\u201d = operation, \u201cshop\u201d = real artists like GZA, \u201cstolen art\u201d = the products sold in the \u201cshop\u201d.\n\nUntalented artists, who aren\u2019t capable of producing their own hits, plan to appear creative, smart and innovative by stealing the \u201cart\u201d of real artists like GZA. So, it was the fake artist\u2019s plan to steal from the shop because (as it shows in the next line) the fake artist has a \u201cswollen heart from not rolling smart\u201d.\n\nGZA is talking about Hip Hop plagiarism.',
#                    u'310528': u'Note that this talk of stations comes between a line about radios and a line about trains.',
#                    u'32551': u'This is an excerpt from 1980\u2019s Shogun Assassin, a martial arts movie released in Japan based on the graphic novel \u201cLone wolf and cub\u201d. This particular piece of dialogue occurs in the beginning of the film, spoken right before the title sequence\n\n\n\nThe sample sets the mood for Liquid Swords: gritty, violent and dark\n\nThe Wu-Tang Clan have never hid their affinity for Asian culture and media, and have sampled many different movies from the region.\n\nFun fact: RZA\u2019s 36 Chambers studio was flooded out just as production of Liquid Swords was finishing, and although the album was mostly completed, all studio equipment was more or less destroyed. In his 2nd book The Tao of Wu, RZA speaks on how this sample set the tone, not just for the Liquid Swords album, but for the Wu-Tang Clan as a whole after that flood.\n\nPost-release:\n\nThe monologue also appears in Quentin Tarantino\u2019s Kill Bill Vol. 2, when Bill + Beatrix\u2019s daughter BB is lulled to sleep by watching Shogun Assassin before her mom lays her dad to waste.\n\nAs Tarantino is an avid Wu-Tang fan and close homie of RZA, this is undoubtedly a nod to \u2018Liquid Swords\u2019.\n\nhttp://www.youtube.com/watch?v=WAWyHcAUfjg&t=1m30s',
#                    u'32552': u"The chorus of this song, \u201cwhen the mc\u2019s came\u2026\u201d is from Gza, Rza, and ODB\u2019s old act. Hence, they\u2019re taking it back to where it came from, preparing the listener to be \u2018schooled\u2019 in the art of hip-hop. A firm believer that Wu-Tang is the purest form of hip-hop, RZA often states things similar to this in songs. He simply wishes to remind people that they are pioneers of hip-hop and people should recognize where other rappers may have gotten their style from. As with so many Wu-Tang lyrics, \u2018Do the Knowledge\u2019 is a Five-Percenter reference, in this case to the 120 Lessons\n\nAlso it is a classic Willie Mitchell instrumental titled \u201cGroovin'\u201d that was used for the track. This comes in as the shift in samples takes place. This makes a reference to the soul music that heavily influenced much of the Wu Tang library, as noted in Shaolin Soul Vol 1 and 2. Meant as a post response to the interlude from a classic kung fu film, that many Wu-Tang members incorporate into their on stage personas and lyrics.",
#                    u'33050': u'GZA explaining what a battle will mean: You\u2019ll get flipped, cut, chopped, and the like. His flow is smooth and constant, and his lyrics is dope to us lyrical addicts',
#                    u'33063': u'Medina is the second holy land of Islam and the burial place of the prophet Muhammad.\n\nIt\u2019s also Five Percenter slang for Brooklyn, where GZA is originally from. Pelan is the Bronx, Mecca is Manhattan/Harlem, and The Desert is Queens.',
#                    u'3490694': u"\u201cLiquid Swords\u201d is the title track and first song on GZA\u2019s classic album. RZA is featured on the hook, while GZA produces two outstanding verses that exemplify his ability to make every word bite and snarl\n\nFrom GZA himself, in an interview:\n\n\u201cThis track is just braggadocios. It isn\u2019t meant to stand for anything. I\u2019m talking about my skills and how I\u2019m better than the rest. Usually I take a beat home and write to it for a few days, but it wasn\u2019t like that with this track. I think RZA played the beat for me and I just spit to it right there. The hook was actually a routine from around \u201884 that me, RZA, and Ol' Dirty would do.\u201d\n\nTrue to form, GZA drops 11 similes and 13 metaphors in just his two verses on this track.",
#                    u'35243': u'Another Shogun Assassin reference. The phrase \u201cchild educator\u201d also reminds me of a line from a certain classic song',
#                    u'35654': u'A reference to the 1960\u2019s television series Mission Impossible, which was later turned into a movie franchise',
#                    u'36072': u'A reference to the song Clan in Da Front, GZA\u2019s solo track from Wu-Tang Clan\u2019s debut album Enter the Wu-Tang. GZA is also referring to the Clan itself.',
#                    u'38751': u'It\u2019s true\u2014and the teeny speakers in my iPhone are even worse!',
#                    u'38752': u'A reference to LL Cool J\u2019s classic \u2018Rock the Bells,\u2019 (which originally had a Bob James sample instead of the Rick-Rubinized rock guitars)',
#                    u'41974': u'GZA disses other rappers with poor lyricism while also dissing the fashion choice of wearing zodiac sign sweatshirts',
#                    u'41977': u'Table stacks (steaks) a verse on the gamble. So my energy is felt once the cards are dealt because I\u2019m talking about gambling.GZA is so wealthy that his minimum bet in poker is so high others would think twice before matching it\n\nOnce the cards are dealt, the weight of the money riding on the hand makes it seem like his opponents have been hit by black belts and cyclones due to how good GZA\u2019s luck is\n\nIn the second half of these rhymes it becomes clear that he uses the card game gamble as a metaphor for his rap battling skills, his minimum bet is a verse and the energy is felt when they\u2019re battling. Then the GZA hits the verse with the impact of roundhouse kicks from black belts attacking the mic like cyclones or typhoons, it has nothing to do with his gambling and luck!',
#                    u'41979': u'He doesn\u2019t write pages of bad lyrics. He considers what he\u2019s going to write before putting it on paper.\n\nThis line specifically refers to how this track was recorded: He doesn\u2019t need ink and paper to be able to rap, referring to his skill to construct (and store) rhymes in his mind and spit them out in the form of freestyle if and when ever necessary.',
#                    u'41980': u'Train metaphors \u2014 your plan gets \u201cderailed\u201d like an Amtrak train, which had a series of bad derailments in the mid-1990s.',
#                    u'41986': u'GZA\u2019s songs are completely different from other rapper\u2019s, and once you get into them it will be hard for you to get out\n\nAlso a reference to Wu Tang\u2019s debut album that dropped a few years prior. \u201cWide entrance\u201d may mean as in the wide variety of good artists in Wu Tang.',
#                    u'420096': u'1) Doesn\u2019t really cover that much of your foot\n2) Aren\u2019t particularly tough.',
#                    u'61536': u'Unlike most rappers, GZA sticks nicely to just the role of judge, unlike the judge-jury-executioner combo of most rappers.\n\nAllah Justice is GZA\u2019s Nations of Gods and Earths name.',
#                    u'61537': u'A play on state penitentiaries and pens used to write rhymes.',
#                    u'61538': u'GZA rhymes have cement-burrowing power than even radio waves can\u2019t match.',
#                    u'62529': u'Either this logo or the Wu logo. I have a vaccination mark. Anyone over 30 or 40 years old in America has one. It\u2019s like a barcode.',
#                    u'72164': u'\u201cMark 5\u201d sneakers are Roman-style sneaks with the strap at the ankle (if \u2014 like me \u2014 you have weak arches, then you should get a pair!)\n\n\n\nIs this meant to be a diss? I would take it as a compliment..',
#                    u'853093': u'When GZA puffs, he makes sure it\u2019s natural. None of that fake shit.',
#                    u'863644': u'When GZA spits his rhymes, these other rappers aren\u2019t so indestructible after all.'},
#  u'lyrics': {u'featuringArtists': [],
#              u'mainArtist': u'',
#              u'producingArtists': [u'RZA'],
#              u'sections': [{u'name': u'[Spoken Dialogue]',
#                             u'verses': [{u'content': u"When I was little, my father was famous\nHe was the greatest samurai in the empire\nAnd he was the Shogun's decapitator\nHe cut off the heads of a hundred and thirty-one lords\nIt was a bad time for the empire\nThe Shogun just stayed inside his castle and he never came out\nPeople said his brain was infected by devils\nMy father would come home, he would forget about the killings\nHe wasn't scared of the Shogun, but the Shogun was scared of him\nMaybe that was the problem\nThen, one night, the Shogun sent his ninja spies to our house\nThey were supposed to kill my father but they didn't\nThat was the night everything changed...\n\n\n",
#                                          u'id': 32551}]},
#                            {u'name': u'[Intro: RZA]',
#                             u'verses': [{u'content': u"See, sometimes\nYou gotta flash em back\nSee niggas don't know where this shit started\nY'all know where it came from\nI'm saying we gonna take y'all back to the source\nDo the knowledge... yo!\n\n\n",
#                                          u'id': 32552}]},
#                            {u'name': u'[Hook: RZA, GZA]',
#                             u'verses': [{u'content': u'When the MCs came to live out the name and to perform\n',
#                                          u'id': 1463153},
#                                         {u'content': u'Some had to snort cocaine to act insane before Pete Rock-ed it on\n',
#                                          u'id': 1463155},
#                                         {u'content': u'Now on with the mental plane to spark the brain with the building to be born\n',
#                                          u'id': 1463158},
#                                         {u'content': u'Yo RZA flip the track with the what to cut...\n\n\n',
#                                          u'id': 1463156}]},
#                            {u'name': u'[Verse 1: GZA]',
#                             u'verses': [{u'content': u'Fake niggas get flipped\nIn mic fights I swing swords and cut clowns\n',
#                                          u'id': 33050},
#                                         {u'content': u'Shit is too swift to bite you record and write it down\n',
#                                          u'id': 114125},
#                                         {u'content': u'I flow like the blood on a murder scene, like a syringe\nOn some wild out shit, to insert a fiend\n',
#                                          u'id': 1472081},
#                                         {u'content': u'But it was your op the shop stolen art\n',
#                                          u'id': 1774226},
#                                         {u'content': u'Catch a swollen heart from not rolling smart\n',
#                                          u'id': 1266684},
#                                         {u'content': u"I put mad pressure, on phony wack rhymes that get hurt\nShit's played like zodiac signs on sweatshirt\n",
#                                          u'id': 41974},
#                                         {u'content': u"That's minimum, and feminine like sandals\n",
#                                          u'id': 420096},
#                                         {u'content': u'My minimum table stacks a verse on a gamble\nEnergy is felt once the cards are dealt\nWith the impact of roundhouse kicks from black belts\nThat attack, the mic-fones like cyclones or typhoon\n',
#                                          u'id': 41977},
#                                         {u'content': u'I represent from midnight to high noon\n',
#                                          u'id': 122135},
#                                         {u'content': u"I don't waste ink, nigga I think\n",
#                                          u'id': 41979},
#                                         {u'content': u'I drop megaton bombs more faster than you blink\nCause rhyme thoughts travel at a tremendous speed\n',
#                                          u'id': 152367},
#                                         {u'content': u'Clouds of smoke, of natural blends of weed\n',
#                                          u'id': 853093},
#                                         {u'content': u"Only under one circumstance that's if I'm blunted\nTurn that shit up,",
#                                          u'id': 1741918},
#                                         {u'content': u'my clan in the front want it\n\n\n\n\n',
#                                          u'id': 36072}]},
#                            {u'name': u'[Hook]', u'verses': []},
#                            {u'name': u'[Verse 2: GZA]',
#                             u'verses': [{u'content': u"I'm on a mission that niggas say is impossible\n",
#                                          u'id': 35654},
#                                         {u'content': u'But when I swing my swords they all choppable\n',
#                                          u'id': 863644},
#                                         {u'content': u'I be the body dropper, the heartbeat stopper\nChild educator, plus head amputator\n',
#                                          u'id': 35243},
#                                         {u'content': u'Cause niggas styles are old like Mark 5 sneakers\n',
#                                          u'id': 72164},
#                                         {u'content': u'Lyrics are weak like clock radio speakers\n',
#                                          u'id': 38751},
#                                         {u'content': u"Don't even stop in my stationand attack\n",
#                                          u'id': 310528},
#                                         {u'content': u'While your plan failed, get derailed like Amtrak\nWhat the fuck for?',
#                                          u'id': 41980},
#                                         {u'content': u'Down by law,',
#                                          u'id': 105123},
#                                         {u'content': u'I make law\n',
#                                          u'id': 1741926},
#                                         {u'content': u'I be justice, I sentence that ass two to four\nRound the clock, that state pen time check it\n',
#                                          u'id': 61536},
#                                         {u'content': u"With the pens I be sticking but you can't stick to crime\n",
#                                          u'id': 61537},
#                                         {u'content': u'Came through with the Wu,',
#                                          u'id': 1266694},
#                                         {u'content': u'slid off on the DL\n',
#                                          u'id': 159234},
#                                         {u'content': u"I'm low-key like seashells,",
#                                          u'id': 122127},
#                                         {u'content': u'I rock these bells\nNow come aboard,',
#                                          u'id': 38752},
#                                         {u'content': u"it's Medina bound\n",
#                                          u'id': 33063},
#                                         {u'content': u"Enter the chamber, and it's a whole different sound\nIt's a wide entrance, small exit like a funnel\n",
#                                          u'id': 41986},
#                                         {u'content': u"So deep it's picked up on radios in tunnels\n",
#                                          u'id': 61538},
#                                         {u'content': u'Niggas are fascinated how the shit begin\nGet vaccinated,',
#                                          u'id': 1291703},
#                                         {u'content': u'my logois branded in your skin\n\n',
#                                          u'id': 62529}]},
#                            {u'name': u'[Hook]', u'verses': []}],
#              u'songId': 951,
#              u'songTitle': u''}}

# %%
decoded_data.viewkeys()
# Out:
# dict_keys([u'explanations', u'lyrics'])

# %%
decoded_data.get('lyrics')
# Out:
# {u'featuringArtists': [],
#  u'mainArtist': u'',
#  u'producingArtists': [u'RZA'],
#  u'sections': [{u'name': u'[Spoken Dialogue]',
#    u'verses': [{u'content': u"When I was little, my father was famous\nHe was the greatest samurai in the empire\nAnd he was the Shogun's decapitator\nHe cut off the heads of a hundred and thirty-one lords\nIt was a bad time for the empire\nThe Shogun just stayed inside his castle and he never came out\nPeople said his brain was infected by devils\nMy father would come home, he would forget about the killings\nHe wasn't scared of the Shogun, but the Shogun was scared of him\nMaybe that was the problem\nThen, one night, the Shogun sent his ninja spies to our house\nThey were supposed to kill my father but they didn't\nThat was the night everything changed...\n\n\n",
#      u'id': 32551}]},
#   {u'name': u'[Intro: RZA]',
#    u'verses': [{u'content': u"See, sometimes\nYou gotta flash em back\nSee niggas don't know where this shit started\nY'all know where it came from\nI'm saying we gonna take y'all back to the source\nDo the knowledge... yo!\n\n\n",
#      u'id': 32552}]},
#   {u'name': u'[Hook: RZA, GZA]',
#    u'verses': [{u'content': u'When the MCs came to live out the name and to perform\n',
#      u'id': 1463153},
#     {u'content': u'Some had to snort cocaine to act insane before Pete Rock-ed it on\n',
#      u'id': 1463155},
#     {u'content': u'Now on with the mental plane to spark the brain with the building to be born\n',
#      u'id': 1463158},
#     {u'content': u'Yo RZA flip the track with the what to cut...\n\n\n',
#      u'id': 1463156}]},
#   {u'name': u'[Verse 1: GZA]',
#    u'verses': [{u'content': u'Fake niggas get flipped\nIn mic fights I swing swords and cut clowns\n',
#      u'id': 33050},
#     {u'content': u'Shit is too swift to bite you record and write it down\n',
#      u'id': 114125},
#     {u'content': u'I flow like the blood on a murder scene, like a syringe\nOn some wild out shit, to insert a fiend\n',
#      u'id': 1472081},
#     {u'content': u'But it was your op the shop stolen art\n', u'id': 1774226},
#     {u'content': u'Catch a swollen heart from not rolling smart\n',
#      u'id': 1266684},
#     {u'content': u"I put mad pressure, on phony wack rhymes that get hurt\nShit's played like zodiac signs on sweatshirt\n",
#      u'id': 41974},
#     {u'content': u"That's minimum, and feminine like sandals\n",
#      u'id': 420096},
#     {u'content': u'My minimum table stacks a verse on a gamble\nEnergy is felt once the cards are dealt\nWith the impact of roundhouse kicks from black belts\nThat attack, the mic-fones like cyclones or typhoon\n',
#      u'id': 41977},
#     {u'content': u'I represent from midnight to high noon\n', u'id': 122135},
#     {u'content': u"I don't waste ink, nigga I think\n", u'id': 41979},
#     {u'content': u'I drop megaton bombs more faster than you blink\nCause rhyme thoughts travel at a tremendous speed\n',
#      u'id': 152367},
#     {u'content': u'Clouds of smoke, of natural blends of weed\n',
#      u'id': 853093},
#     {u'content': u"Only under one circumstance that's if I'm blunted\nTurn that shit up,",
#      u'id': 1741918},
#     {u'content': u'my clan in the front want it\n\n\n\n\n', u'id': 36072}]},
#   {u'name': u'[Hook]', u'verses': []},
#   {u'name': u'[Verse 2: GZA]',
#    u'verses': [{u'content': u"I'm on a mission that niggas say is impossible\n",
#      u'id': 35654},
#     {u'content': u'But when I swing my swords they all choppable\n',
#      u'id': 863644},
#     {u'content': u'I be the body dropper, the heartbeat stopper\nChild educator, plus head amputator\n',
#      u'id': 35243},
#     {u'content': u'Cause niggas styles are old like Mark 5 sneakers\n',
#      u'id': 72164},
#     {u'content': u'Lyrics are weak like clock radio speakers\n', u'id': 38751},
#     {u'content': u"Don't even stop in my stationand attack\n", u'id': 310528},
#     {u'content': u'While your plan failed, get derailed like Amtrak\nWhat the fuck for?',
#      u'id': 41980},
#     {u'content': u'Down by law,', u'id': 105123},
#     {u'content': u'I make law\n', u'id': 1741926},
#     {u'content': u'I be justice, I sentence that ass two to four\nRound the clock, that state pen time check it\n',
#      u'id': 61536},
#     {u'content': u"With the pens I be sticking but you can't stick to crime\n",
#      u'id': 61537},
#     {u'content': u'Came through with the Wu,', u'id': 1266694},
#     {u'content': u'slid off on the DL\n', u'id': 159234},
#     {u'content': u"I'm low-key like seashells,", u'id': 122127},
#     {u'content': u'I rock these bells\nNow come aboard,', u'id': 38752},
#     {u'content': u"it's Medina bound\n", u'id': 33063},
#     {u'content': u"Enter the chamber, and it's a whole different sound\nIt's a wide entrance, small exit like a funnel\n",
#      u'id': 41986},
#     {u'content': u"So deep it's picked up on radios in tunnels\n",
#      u'id': 61538},
#     {u'content': u'Niggas are fascinated how the shit begin\nGet vaccinated,',
#      u'id': 1291703},
#     {u'content': u'my logois branded in your skin\n\n', u'id': 62529}]},
#   {u'name': u'[Hook]', u'verses': []}],
#  u'songId': 951,
#  u'songTitle': u''}

# %%
Data_under_investigation = decoded_data.get('lyrics')

# %%
Data_under_investigation.viewkeys()
# Out:
# dict_keys([u'songId', u'featuringArtists', u'mainArtist', u'producingArtists', u'sections', u'songTitle'])

# %%
Data_under_investigation = decoded_data.get('lyrics').get('sections')

# %%
Data_under_investigation
# Out:
# [{u'name': u'[Spoken Dialogue]',
#   u'verses': [{u'content': u"When I was little, my father was famous\nHe was the greatest samurai in the empire\nAnd he was the Shogun's decapitator\nHe cut off the heads of a hundred and thirty-one lords\nIt was a bad time for the empire\nThe Shogun just stayed inside his castle and he never came out\nPeople said his brain was infected by devils\nMy father would come home, he would forget about the killings\nHe wasn't scared of the Shogun, but the Shogun was scared of him\nMaybe that was the problem\nThen, one night, the Shogun sent his ninja spies to our house\nThey were supposed to kill my father but they didn't\nThat was the night everything changed...\n\n\n",
#     u'id': 32551}]},
#  {u'name': u'[Intro: RZA]',
#   u'verses': [{u'content': u"See, sometimes\nYou gotta flash em back\nSee niggas don't know where this shit started\nY'all know where it came from\nI'm saying we gonna take y'all back to the source\nDo the knowledge... yo!\n\n\n",
#     u'id': 32552}]},
#  {u'name': u'[Hook: RZA, GZA]',
#   u'verses': [{u'content': u'When the MCs came to live out the name and to perform\n',
#     u'id': 1463153},
#    {u'content': u'Some had to snort cocaine to act insane before Pete Rock-ed it on\n',
#     u'id': 1463155},
#    {u'content': u'Now on with the mental plane to spark the brain with the building to be born\n',
#     u'id': 1463158},
#    {u'content': u'Yo RZA flip the track with the what to cut...\n\n\n',
#     u'id': 1463156}]},
#  {u'name': u'[Verse 1: GZA]',
#   u'verses': [{u'content': u'Fake niggas get flipped\nIn mic fights I swing swords and cut clowns\n',
#     u'id': 33050},
#    {u'content': u'Shit is too swift to bite you record and write it down\n',
#     u'id': 114125},
#    {u'content': u'I flow like the blood on a murder scene, like a syringe\nOn some wild out shit, to insert a fiend\n',
#     u'id': 1472081},
#    {u'content': u'But it was your op the shop stolen art\n', u'id': 1774226},
#    {u'content': u'Catch a swollen heart from not rolling smart\n',
#     u'id': 1266684},
#    {u'content': u"I put mad pressure, on phony wack rhymes that get hurt\nShit's played like zodiac signs on sweatshirt\n",
#     u'id': 41974},
#    {u'content': u"That's minimum, and feminine like sandals\n", u'id': 420096},
#    {u'content': u'My minimum table stacks a verse on a gamble\nEnergy is felt once the cards are dealt\nWith the impact of roundhouse kicks from black belts\nThat attack, the mic-fones like cyclones or typhoon\n',
#     u'id': 41977},
#    {u'content': u'I represent from midnight to high noon\n', u'id': 122135},
#    {u'content': u"I don't waste ink, nigga I think\n", u'id': 41979},
#    {u'content': u'I drop megaton bombs more faster than you blink\nCause rhyme thoughts travel at a tremendous speed\n',
#     u'id': 152367},
#    {u'content': u'Clouds of smoke, of natural blends of weed\n',
#     u'id': 853093},
#    {u'content': u"Only under one circumstance that's if I'm blunted\nTurn that shit up,",
#     u'id': 1741918},
#    {u'content': u'my clan in the front want it\n\n\n\n\n', u'id': 36072}]},
#  {u'name': u'[Hook]', u'verses': []},
#  {u'name': u'[Verse 2: GZA]',
#   u'verses': [{u'content': u"I'm on a mission that niggas say is impossible\n",
#     u'id': 35654},
#    {u'content': u'But when I swing my swords they all choppable\n',
#     u'id': 863644},
#    {u'content': u'I be the body dropper, the heartbeat stopper\nChild educator, plus head amputator\n',
#     u'id': 35243},
#    {u'content': u'Cause niggas styles are old like Mark 5 sneakers\n',
#     u'id': 72164},
#    {u'content': u'Lyrics are weak like clock radio speakers\n', u'id': 38751},
#    {u'content': u"Don't even stop in my stationand attack\n", u'id': 310528},
#    {u'content': u'While your plan failed, get derailed like Amtrak\nWhat the fuck for?',
#     u'id': 41980},
#    {u'content': u'Down by law,', u'id': 105123},
#    {u'content': u'I make law\n', u'id': 1741926},
#    {u'content': u'I be justice, I sentence that ass two to four\nRound the clock, that state pen time check it\n',
#     u'id': 61536},
#    {u'content': u"With the pens I be sticking but you can't stick to crime\n",
#     u'id': 61537},
#    {u'content': u'Came through with the Wu,', u'id': 1266694},
#    {u'content': u'slid off on the DL\n', u'id': 159234},
#    {u'content': u"I'm low-key like seashells,", u'id': 122127},
#    {u'content': u'I rock these bells\nNow come aboard,', u'id': 38752},
#    {u'content': u"it's Medina bound\n", u'id': 33063},
#    {u'content': u"Enter the chamber, and it's a whole different sound\nIt's a wide entrance, small exit like a funnel\n",
#     u'id': 41986},
#    {u'content': u"So deep it's picked up on radios in tunnels\n",
#     u'id': 61538},
#    {u'content': u'Niggas are fascinated how the shit begin\nGet vaccinated,',
#     u'id': 1291703},
#    {u'content': u'my logois branded in your skin\n\n', u'id': 62529}]},
#  {u'name': u'[Hook]', u'verses': []}]

# %%
len(Data_under_investigation)
# Out:
# 7

# %%
Data_under_investigation[0]
# Out:
# {u'name': u'[Spoken Dialogue]',
#  u'verses': [{u'content': u"When I was little, my father was famous\nHe was the greatest samurai in the empire\nAnd he was the Shogun's decapitator\nHe cut off the heads of a hundred and thirty-one lords\nIt was a bad time for the empire\nThe Shogun just stayed inside his castle and he never came out\nPeople said his brain was infected by devils\nMy father would come home, he would forget about the killings\nHe wasn't scared of the Shogun, but the Shogun was scared of him\nMaybe that was the problem\nThen, one night, the Shogun sent his ninja spies to our house\nThey were supposed to kill my father but they didn't\nThat was the night everything changed...\n\n\n",
#    u'id': 32551}]}

# %%
Data_under_investigation[1]
# Out:
# {u'name': u'[Intro: RZA]',
#  u'verses': [{u'content': u"See, sometimes\nYou gotta flash em back\nSee niggas don't know where this shit started\nY'all know where it came from\nI'm saying we gonna take y'all back to the source\nDo the knowledge... yo!\n\n\n",
#    u'id': 32552}]}

# %%
type(Data_under_investigation)
# Out:
# list

# %%
dict(Data_under_investigation)
# Out:
# {u'verses': u'name'}
